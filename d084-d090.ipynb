# %% [markdown]
# ENSINAMENTOS

# %%
teste = list()
teste.append("Kaich")
teste.append(18)
galera = list()
galera.append(teste[:])
teste[0] = "Otávio"
teste[1] = 9
galera.append(teste[:])
print(galera)
# Out:
# ['Otávio', 9]
# [['Kaich', 18], ['Otávio', 9]]

# %%
galera = [["Miguel", 18, "Homem"], ["Anna", 17, "Moça"], ["Gil", 33, "Homem"], ["Maria", 12, "Criança"]]
print(galera[2][0])
print(galera[1][2])
print(galera[0][1])
# Out:
# Gil
# Moça
# 18
